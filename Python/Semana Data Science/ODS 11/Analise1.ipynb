# %%
import pandas as pd
import numpy as np
import matplotlib as mp

# %%
? pd.read_csv

# %%
data_metro_2016 = pd.read_csv('data\datamodaisrj_metro_2016.csv', sep=';')

# %%
data_metro_2016
# Out:
#                 Bairros Total anual Média diária
# 0                 Saúde           -            -
# 1                Gamboa           -            -
# 2          Santo Cristo           -            -
# 3                  Caju           -            -
# 4                Centro      72 483          199
# ..                  ...         ...          ...
# 156          Santa Cruz           -            -
# 157            Sepetiba           -            -
# 158           Guaratiba           -            -
# 159  Barra de Guaratiba           -            -
# 160  Pedra de Guaratiba           -            -
#
# [161 rows x 3 columns]

# %%
data_metro_2017 = pd.read_csv('data\datamodaisrj_metro_2017.csv', sep=';')

# %%
data_metro_2017
# Out:
#                 Bairros Total anual Média diária
# 0                 Saúde           -            -
# 1                Gamboa           -            -
# 2          Santo Cristo           -            -
# 3                  Caju           -            -
# 4                Centro      66 654          183
# ..                  ...         ...          ...
# 156          Santa Cruz           -            -
# 157            Sepetiba           -            -
# 158           Guaratiba           -            -
# 159  Barra de Guaratiba           -            -
# 160  Pedra de Guaratiba           -            -
#
# [161 rows x 3 columns]

# %%
data_trem_2016 = pd.read_csv('data\datamodaisrj_trem_2016.csv', sep=';')

# %%
data_trem_2016
# Out:
#                 Bairros Total anual Média diária
# 0                 Saúde           -            -
# 1                Gamboa           -            -
# 2          Santo Cristo           -            -
# 3                  Caju           -            -
# 4                Centro      40 478          111
# ..                  ...         ...          ...
# 156          Santa Cruz       4 595           13
# 157            Sepetiba           -            -
# 158           Guaratiba           -            -
# 159  Barra de Guaratiba           -            -
# 160  Pedra de Guaratiba           -            -
#
# [161 rows x 3 columns]

# %%
data_trem_2017 = pd.read_csv('data\datamodaisrj_trem_2017.csv', sep=',')

# %%
data_trem_2017
# Out:
#                 Bairros Total anual Média diária
# 0                 Saúde           -            -
# 1                Gamboa           -            -
# 2          Santo Cristo           -            -
# 3                  Caju           -            -
# 4                Centro      35 873           98
# ..                  ...         ...          ...
# 156          Santa Cruz       4 169           11
# 157            Sepetiba           -            -
# 158           Guaratiba           -            -
# 159  Barra de Guaratiba           -            -
# 160  Pedra de Guaratiba           -            -
#
# [161 rows x 3 columns]

# %%
data_trem_2017 = data_trem_2017[data_trem_2017['Total anual'] != '-']

# %%
data_trem_2017a= data_trem_2017.drop (data_trem_2017['Total anual'].isna())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-2fec78b1bdeb> in <module>
# ----> 1 data_trem_2017a= data_trem_2017.drop (data_trem_2017['Total anual'].isna())
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
data_trem_2017
# Out:
#                     Bairros Total anual Média diária
# 4                    Centro      35 873           98
# 10            São Cristóvão       7 804           21
# 12                 Benfica        1 156            3
# 34        Praça da Bandeira       1 167            3
# 37                 Maracanã       3 224            9
# 41               Manguinhos         668            2
# 42               Bonsucesso       1 816            5
# 43                    Ramos         819            2
# 44                   Olaria         937            3
# 47     São Francisco Xavier         732            2
# 49                Riachuelo       1 160            3
# 50                  Sampaio         505            1
# 51             Engenho Novo       1 172            3
# 53                    Méier       4 097           11
# 56        Engenho de Dentro       3 179            9
# 59                  Piedade         901            2
# 61                  Pilares         235            1
# ...

# %%
estacoes_trem = pd.read_csv ('data\Estacoes_Trem.csv',sep=',')

# %%
estacoes_trem
# Out:
#                X             Y  OBJECTID  Cod                    Nome  \
# 0    659240.5000  7.482178e+06         1   60             Nova Iguaçu
# 1    655197.3795  7.484056e+06         2   20       Comendador Soares
# 2    651756.0969  7.486730e+06         3    4                  Austin
# 3    648330.8010  7.487214e+06         4   81               Queimados
# 4    643238.5383  7.491415e+06         5   29     Engenheiro Pedreira
# ..           ...           ...       ...  ...                     ...
# 99   662749.9689  7.476772e+06       100   59               Nilópolis
# 100  661350.7989  7.479739e+06       101   57                Mesquita
# 101  663222.9125  7.475860e+06       102   62                  Olinda
# 102  664401.8915  7.473383e+06       103   86  Ricardo de Albuquerque
# 103  660796.1724  7.481100e+06       104   80    Presidente Juscelino
#
#     Flg_IntegraOnibus Flg_IntegraMetro Flg_Terminal Flg_TransfRamal  \
# ...

# %%
estacoes_metro = pd.read_csv('data\Estacoes_Metro.csv', sep=',')

# %%
estacoes_metro
# Out:
#               X             Y  OBJECTID  Cod                      Nome  \
# 0   667866.2673  7.477003e+06         1    1                    Pavuna
# 1   668510.9902  7.475928e+06         2    2   Engenheiro Rubens Paiva
# 2   669405.0928  7.475004e+06         3    3  Acari / Fazenda Botafogo
# 3   670051.9240  7.474226e+06         4    4               Coelho Neto
# 4   671002.2546  7.472974e+06         5    5                   Colégio
# 5   672080.2129  7.472379e+06         6    6                     Irajá
# 6   673122.7026  7.471690e+06         7    7       Vicente de Carvalho
# 7   673758.3954  7.470759e+06         8    8              Tomaz Coelho
# 8   674711.3483  7.470145e+06         9    9         Engenho da Rainha
# 9   676143.2284  7.469385e+06        10   10                   Inhauma
# 10  677318.7123  7.468848e+06        11   11              Del Castilho
# 11  678502.9045  7.468584e+06        12   12            Maria da Graça
# ...
