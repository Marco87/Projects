# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# # Deputados

# %%
deputados = pd.read_csv("Dados/deputados.csv", sep=";", parse_dates=['dataNascimento', 'dataFalecimento'])

# %%
deputados.head()[:5]
# Out:
#                                                  uri          nome  \
# 0  https://dadosabertos.camara.leg.br/api/v2/depu...    LOPES GAMA
# 1  https://dadosabertos.camara.leg.br/api/v2/depu...      CARNEIRO
# 2  https://dadosabertos.camara.leg.br/api/v2/depu...        CALMON
# 3  https://dadosabertos.camara.leg.br/api/v2/depu...     MONTEZUMA
# 4  https://dadosabertos.camara.leg.br/api/v2/depu...  SILVA LISBOA
#
#    idLegislaturaInicial  idLegislaturaFinal                       nomeCivil  \
# 0                     1                   2        Caetano Maria Lopes Gama
# 1                     1                   1    Francisco Carneiro de Campos
# 2                     1                   4  Miguel Calmon Du Pin e Almeida
# 3                     2                   8  Francisco Gê Acayaba Montezuma
# 4                     1                   1            José da Silva Lisboa
#
#    cpf siglaSexo urlRedeSocial urlWebsite dataNascimento dataFalecimento  \
# ...

# %%
deputados2 = deputados.drop(['idLegislaturaInicial', 'cpf', 'urlRedeSocial', 'dataFalecimento', 'urlWebsite', 'urlRedeSocial',
                     'idLegislaturaFinal', 'uri'], axis=1)

# %%
deputados2['nome'][:5]
# Out:
# 0      LOPES GAMA
# 1        CARNEIRO
# 2          CALMON
# 3       MONTEZUMA
# 4    SILVA LISBOA
# Name: nome, dtype: object

# %%
deputados['ufNascimento'].value_counts()[:5]
# Out:
# MG    793
# SP    752
# RJ    618
# RS    492
# BA    473
# Name: ufNascimento, dtype: int64

# %% [markdown]
# # Frentes

# %%
frentes = pd.read_csv("Dados/frentes.csv", sep=";", parse_dates=['dataCriacao'])

# %%
frentes[:5]
# Out:
#       id                                                uri  \
# 0  53249  https://dadosabertos.camara.leg.br/api/v2/fren...
# 1  53250  https://dadosabertos.camara.leg.br/api/v2/fren...
# 2  53251  https://dadosabertos.camara.leg.br/api/v2/fren...
# 3  53252  https://dadosabertos.camara.leg.br/api/v2/fren...
# 4  53253  https://dadosabertos.camara.leg.br/api/v2/fren...
#
#                                               titulo dataCriacao  \
# 0              Frente Parlamentar Mista da Habitação  2007-06-11
# 1  Frente Parlamentar em Apoio e Fortalecimento d...  2007-06-14
# 2         Frente Parlamentar da Agricultura Familiar  2007-06-15
# 3                        Frente Parlamentar da Terra  2007-08-14
# 4  Frente Parlamentar de Apoio as Santas Casas de...  2007-07-10
#
#    idLegislatura   telefone  email  keywords  idSituacao  \
# 0             53  3215-5569    NaN       NaN         NaN
# 1             53  3215-5313    NaN       NaN         NaN
# ...

# %%
frentes['dataCriacao'].sort_values(ascending=False)[:15]
# Out:
# 1038   2019-11-25
# 1036   2019-11-21
# 1030   2019-11-19
# 1032   2019-11-19
# 1010   2019-11-19
# 1029   2019-11-12
# 1019   2019-11-12
# 1033   2019-11-12
# 1035   2019-11-12
# 1012   2019-11-11
# 1021   2019-11-11
# 1022   2019-11-05
# 1024   2019-11-05
# 1026   2019-11-05
# 1027   2019-11-05
# Name: dataCriacao, dtype: datetime64[ns]

# %% [markdown]
# # Frentes Deputados

# %%
frentes_deputados = pd.read_csv("Dados/frentesDeputados.csv", sep=";", parse_dates=['dataInicio', 'dataFim'])

# %%
frentes_deputados[:5]
# Out:
#       id                                                uri  \
# 0  54213  https://dadosabertos.camara.leg.br/api/v2/fren...
# 1  54213  https://dadosabertos.camara.leg.br/api/v2/fren...
# 2  54213  https://dadosabertos.camara.leg.br/api/v2/fren...
# 3  54213  https://dadosabertos.camara.leg.br/api/v2/fren...
# 4  54213  https://dadosabertos.camara.leg.br/api/v2/fren...
#
#                                               titulo  deputado_.id  \
# 0  Frente Parlamentar pela Defesa e Valorização d...      204451.0
# 1  Frente Parlamentar pela Defesa e Valorização d...      204554.0
# 2  Frente Parlamentar pela Defesa e Valorização d...      204521.0
# 3  Frente Parlamentar pela Defesa e Valorização d...      204379.0
# 4  Frente Parlamentar pela Defesa e Valorização d...      204560.0
#
#                                        deputado_.uri  \
# 0  https://dadosabertos.camara.leg.br/api/v2/depu...
# 1  https://dadosabertos.camara.leg.br/api/v2/depu...
# ...
