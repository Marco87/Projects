# %%
#Importando as bibliotecas

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#Importando os dados e salvando e um dataframe

df = pd.read_csv("comp_bikes_mod.csv")

# %%
#Exibindo o dataframe

df
# Out:
#        instant      dteday  season   yr  mnth    hr  holiday  weekday  \
# 0          1.0         NaN     1.0  0.0   1.0   0.0      0.0      6.0
# 1          2.0  2011-01-01     1.0  0.0   1.0   1.0      0.0      6.0
# 2          3.0  2011-01-01     1.0  0.0   1.0   2.0      0.0      6.0
# 3          4.0  2011-01-01     1.0  0.0   1.0   3.0      0.0      6.0
# 4          5.0  2011-01-01     1.0  0.0   1.0   4.0      0.0      6.0
# ...        ...         ...     ...  ...   ...   ...      ...      ...
# 17374  17375.0  2012-12-31     NaN  1.0  12.0  19.0      0.0      1.0
# 17375  17376.0  2012-12-31     1.0  1.0  12.0  20.0      0.0      1.0
# 17376  17377.0         NaN     1.0  1.0  12.0  21.0      0.0      1.0
# 17377      NaN  2012-12-31     1.0  1.0   NaN   NaN      0.0      1.0
# 17378      NaN  2012-12-31     NaN  1.0   NaN  23.0      0.0      1.0
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0             0.0         1.0   NaN  0.2879  0.81     0.0000     3.0
# 1             0.0         NaN  0.22  0.2727  0.80     0.0000     8.0
# 2             0.0         1.0  0.22  0.2727  0.80     0.0000     5.0
# 3             0.0         1.0  0.24  0.2879  0.75     0.0000     3.0
# 4             NaN         1.0  0.24  0.2879  0.75     0.0000     0.0
# ...           ...         ...   ...     ...   ...        ...     ...
# 17374         1.0         2.0  0.26  0.2576  0.60     0.1642    11.0
# 17375         1.0         2.0  0.26  0.2576  0.60     0.1642     NaN
# 17376         1.0         1.0  0.26  0.2576  0.60     0.1642     7.0
# 17377         1.0         1.0  0.26  0.2727  0.56     0.1343    13.0
# 17378         1.0         1.0   NaN  0.2727  0.65     0.1343    12.0
#
#        registered    cnt
# 0            13.0   16.0
# 1            32.0   40.0
# 2            27.0   32.0
# 3            10.0   13.0
# 4             1.0    1.0
# ...           ...    ...
# 17374       108.0  119.0
# 17375         NaN   89.0
# 17376        83.0   90.0
# 17377        48.0   61.0
# 17378        37.0   49.0
#
# [17379 rows x 17 columns]

# %%
#Descrição do dataframe

df.describe()
# Out:
#             instant        season            yr          mnth            hr  \
# count  15641.000000  15641.000000  15641.000000  15641.000000  15641.000000
# mean    8676.513842      2.503420      0.501758      6.536091     11.521258
# std     5010.773755      1.107636      0.500013      3.441490      6.917606
# min        1.000000      1.000000      0.000000      1.000000      0.000000
# 25%     4335.000000      2.000000      0.000000      4.000000      6.000000
# 50%     8678.000000      3.000000      1.000000      7.000000     12.000000
# 75%    13005.000000      3.000000      1.000000     10.000000     17.000000
# max    17377.000000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  15641.000000  15641.000000  15641.000000  15641.000000  15641.000000
# mean       0.028131      2.999233      0.682118      1.423950      0.497062
# std        0.165353      2.005300      0.465668      0.638982      0.192451
# min        0.000000      0.000000      0.000000      1.000000      0.020000
# 25%        0.000000      1.000000      0.000000      1.000000      0.340000
# 50%        0.000000      3.000000      1.000000      1.000000      0.500000
# 75%        0.000000      5.000000      1.000000      2.000000      0.660000
# max        1.000000      6.000000      1.000000      4.000000      1.000000
#
#               atemp           hum     windspeed        casual    registered  \
# count  15641.000000  15641.000000  15641.000000  15641.000000  15641.000000
# mean       0.476281      0.627579      0.189247     35.583147    153.644972
# std        0.172520      0.192893      0.122188     49.226455    151.750573
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.333300      0.480000      0.104500      4.000000     34.000000
# 50%        0.484800      0.630000      0.164200     17.000000    115.000000
# 75%        0.621200      0.780000      0.253700     48.000000    220.000000
# max        1.000000      1.000000      0.850700    367.000000    886.000000
#
#                 cnt
# count  15641.000000
# mean     189.919826
# std      181.972508
# min        1.000000
# 25%       40.000000
# 50%      142.000000
# 75%      281.000000
# max      977.000000

# %%
#Informações do dataframe

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     15641 non-null  float64
#  1   dteday      15641 non-null  object
#  2   season      15641 non-null  float64
#  3   yr          15641 non-null  float64
#  4   mnth        15641 non-null  float64
#  5   hr          15641 non-null  float64
#  6   holiday     15641 non-null  float64
#  7   weekday     15641 non-null  float64
#  8   workingday  15641 non-null  float64
#  9   weathersit  15641 non-null  float64
#  10  temp        15641 non-null  float64
#  11  atemp       15641 non-null  float64
#  12  hum         15641 non-null  float64
#  13  windspeed   15641 non-null  float64
#  14  casual      15641 non-null  float64
#  15  registered  15641 non-null  float64
#  16  cnt         15641 non-null  float64
# dtypes: float64(16), object(1)
# memory usage: 2.3+ MB

# %%
#Tipos de dados contidos no dataframe

df.dtypes
# Out:
# instant       float64
# dteday         object
# season        float64
# yr            float64
# mnth          float64
# hr            float64
# holiday       float64
# weekday       float64
# workingday    float64
# weathersit    float64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual        float64
# registered    float64
# cnt           float64
# dtype: object

# %%
#Gerando um novo dataframe sem as linhas nulas da coluna dteday

df_dteday = df.dropna(subset=['dteday'])

# %%
#Descrição do novo dataframe gerado (feature temp)

df_dteday['temp'].describe()
# Out:
# count    14066.000000
# mean         0.496926
# std          0.192971
# min          0.020000
# 25%          0.340000
# 50%          0.500000
# 75%          0.660000
# max          1.000000
# Name: temp, dtype: float64

# %%
#Descrição do novo dataframe gerado (feature windspeed)

df_dteday['windspeed'].describe()
# Out:
# count    14082.000000
# mean         0.189552
# std          0.122309
# min          0.000000
# 25%          0.104500
# 50%          0.164200
# 75%          0.253700
# max          0.850700
# Name: windspeed, dtype: float64

# %%
#Treinando os dados

X_train, X_test, y_train, y_test = train_test_split(df_dteday, df_dteday.season, test_size = 0.2, random_state = 0)

X_train.shape, X_test.shape
# Out:
# ((12512, 17), (3129, 17))

# %%
#Dataframe sem as linhas nulas da coluna dteday

df_dteday
# Out:
#        instant      dteday  season   yr  mnth    hr  holiday  weekday  \
# 1          2.0  2011-01-01     1.0  0.0   1.0   1.0      0.0      6.0
# 2          3.0  2011-01-01     1.0  0.0   1.0   2.0      0.0      6.0
# 3          4.0  2011-01-01     1.0  0.0   1.0   3.0      0.0      6.0
# 4          5.0  2011-01-01     1.0  0.0   1.0   4.0      0.0      6.0
# 5          6.0  2011-01-01     1.0  0.0   1.0   5.0      0.0      6.0
# ...        ...         ...     ...  ...   ...   ...      ...      ...
# 17373  17374.0  2012-12-31     1.0  1.0  12.0  18.0      0.0      1.0
# 17374  17375.0  2012-12-31     NaN  1.0  12.0  19.0      0.0      1.0
# 17375  17376.0  2012-12-31     1.0  1.0  12.0  20.0      0.0      1.0
# 17377      NaN  2012-12-31     1.0  1.0   NaN   NaN      0.0      1.0
# 17378      NaN  2012-12-31     NaN  1.0   NaN  23.0      0.0      1.0
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 1             0.0         NaN  0.22  0.2727  0.80     0.0000     8.0
# 2             0.0         1.0  0.22  0.2727  0.80     0.0000     5.0
# 3             0.0         1.0  0.24  0.2879  0.75     0.0000     3.0
# 4             NaN         1.0  0.24  0.2879  0.75     0.0000     0.0
# 5             0.0         2.0  0.24  0.2576  0.75     0.0896     0.0
# ...           ...         ...   ...     ...   ...        ...     ...
# 17373         1.0         2.0  0.26     NaN  0.48     0.1343    10.0
# 17374         1.0         2.0  0.26  0.2576  0.60     0.1642    11.0
# 17375         1.0         2.0  0.26  0.2576  0.60     0.1642     NaN
# 17377         1.0         1.0  0.26  0.2727  0.56     0.1343    13.0
# 17378         1.0         1.0   NaN  0.2727  0.65     0.1343    12.0
#
#        registered    cnt
# 1            32.0   40.0
# 2            27.0   32.0
# 3            10.0   13.0
# 4             1.0    1.0
# 5             1.0    1.0
# ...           ...    ...
# 17373       112.0  122.0
# 17374       108.0  119.0
# 17375         NaN   89.0
# 17377        48.0   61.0
# 17378        37.0   49.0
#
# [15641 rows x 17 columns]

# %%
#Convertendo o tipo da feature dteday, de string para datetime

df_dteday['dteday'] = pd.to_datetime(df_dteday['dteday'])
# Out:
# /home/marco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#Exibindo os tipos das features do dataframe df_dteday

df_dteday.dtypes
# Out:
# instant              float64
# dteday        datetime64[ns]
# season               float64
# yr                   float64
# mnth                 float64
# hr                   float64
# holiday              float64
# weekday              float64
# workingday           float64
# weathersit           float64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual               float64
# registered           float64
# cnt                  float64
# dtype: object

# %%
#Descrevendo a feature dteday (verificando as datas mínima e máxima)

df_dteday['dteday'].describe()
# Out:
# count                   15641
# unique                    731
# top       2011-06-04 00:00:00
# freq                       24
# first     2011-01-01 00:00:00
# last      2012-12-31 00:00:00
# Name: dteday, dtype: object

# %%
#Criando um gráfico (boxplot) da feature windspeed

df_dteday.boxplot(column = ['windspeed'])

# %%
#Gerando a matriz de correlação

corr = df_dteday[['season', 'temp', 'atemp', 'hum', 'windspeed', 'cnt']].corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_221799e4_cdde_11ea_a998_5bd9e9090d58row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row0_col1 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row0_col2 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row0_col3 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row0_col4 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row0_col5 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row1_col0 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row1_col2 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row1_col3 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row1_col4 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row1_col5 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row2_col0 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row2_col1 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row2_col3 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row2_col4 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row2_col5 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row3_col0 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row3_col2 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row3_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row3_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row4_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row4_col1 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row4_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row4_col3 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row4_col5 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row5_col0 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row5_col1 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row5_col2 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row5_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row5_col4 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_221799e4_cdde_11ea_a998_5bd9e9090d58row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_221799e4_cdde_11ea_a998_5bd9e9090d58" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >season</th>        <th class="col_heading level0 col1" >temp</th>        <th class="col_heading level0 col2" >atemp</th>        <th class="col_heading level0 col3" >hum</th>        <th class="col_heading level0 col4" >windspeed</th>        <th class="col_heading level0 col5" >cnt</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_221799e4_cdde_11ea_a998_5bd9e9090d58level0_row0" class="row_heading level0 row0" >season</th>
#                         <td id="T_221799e4_cdde_11ea_a998_5bd9e9090d58row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_221799e4_cdde_11ea_a998_5bd9e9090d58row0_col1" class="data row0 col1" >0.31</td>
#                         <td id="T_221799e4_cdde_11ea_a998_5bd9e9090d58row0_col2" class="data row0 col2" >0.32</td>
#                         <td id="T_221799e4_cdde_11ea_a998_5bd9e9090d58row0_col3" class="data row0 col3" >0.15</td>
#                         <td id="T_221799e4_cdde_11ea_a998_5bd9e9090d58row0_col4" class="data row0 col4" >-0.15</td>
#                         <td id="T_221799e4_cdde_11ea_a998_5bd9e9090d58row0_col5" class="data row0 col5" >0.18</td>
#             </tr>
#             <tr>
#                         <th id="T_221799e4_cdde_11ea_a998_5bd9e9090d58level0_row1" class="row_heading level0 row1" >temp</th>
#                         <td id="T_221799e4_cdde_11ea_a998_5bd9e9090d58row1_col0" class="data row1 col0" >0.31</td>
#                         <td id="T_221799e4_cdde_11ea_a998_5bd9e9090d58row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_221799e4_cdde_11ea_a998_5bd9e9090d58row1_col2" class="data row1 col2" >0.99</td>
#                         <td id="T_221799e4_cdde_11ea_a998_5bd9e9090d58row1_col3" class="data row1 col3" >-0.07</td>
#                         <td id="T_221799e4_cdde_11ea_a998_5bd9e9090d58row1_col4" class="data row1 col4" >-0.02</td>
#                         <td id="T_221799e4_cdde_11ea_a998_5bd9e9090d58row1_col5" class="data row1 col5" >0.41</td>
#             </tr>
#             <tr>
#                         <th id="T_221799e4_cdde_11ea_a998_5bd9e9090d58level0_row2" class="row_heading level0 row2" >atemp</th>
#                         <td id="T_221799e4_cdde_11ea_a998_5bd9e9090d58row2_col0" class="data row2 col0" >0.32</td>
#                         <td id="T_221799e4_cdde_11ea_a998_5bd9e9090d58row2_col1" class="data row2 col1" >0.99</td>
#                         <td id="T_221799e4_cdde_11ea_a998_5bd9e9090d58row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_221799e4_cdde_11ea_a998_5bd9e9090d58row2_col3" class="data row2 col3" >-0.05</td>
#                         <td id="T_221799e4_cdde_11ea_a998_5bd9e9090d58row2_col4" class="data row2 col4" >-0.06</td>
#                         <td id="T_221799e4_cdde_11ea_a998_5bd9e9090d58row2_col5" class="data row2 col5" >0.40</td>
#             </tr>
#             <tr>
#                         <th id="T_221799e4_cdde_11ea_a998_5bd9e9090d58level0_row3" class="row_heading level0 row3" >hum</th>

# %%
#Média dos valores da coluna hum

df['hum'].mean()
# Out:
# 0.6275787993095021

# %%
#Média dos valores da coluna cnt

df['cnt'].mean()
# Out:
# 189.91982609807556

# %%
#Trocando as linhas nulas pela média

df['hum'] = df['hum'].fillna(df['hum'].mean())

# %%
#Trocando as linhas nulas pela média

df['cnt'] = df['cnt'].fillna(df['cnt'].mean())

# %%
#Trocando as linhas nulas pela média

df['casual'] = df['casual'].fillna(df['casual'].mean())

# %%
#Fazendo o treinamento com as features hum e cnt

X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(df.hum, df.casual, test_size = 0.3, random_state = 0)

regressor = LinearRegression()
regressor.fit(X_treinamento, y_treinamento)
score = regressor.score(X_treinamento, y_treinamento)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-4d72d5d3743f> in <module>
#       4
#       5 regressor = LinearRegression()
# ----> 6 regressor.fit(X_treinamento, y_treinamento)
#       7 score = regressor.score(X_treinamento, y_treinamento)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     504         n_jobs_ = self.n_jobs
#     505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 506                                    y_numeric=True, multi_output=True)
#     507
#     508         if sample_weight is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     801                     ensure_min_samples=ensure_min_samples,
#     802                     ensure_min_features=ensure_min_features,
# --> 803                     estimator=estimator)
#     804     if multi_output:
#     805         y = check_array(y, accept_sparse='csr', force_all_finite=True,
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     622                     "Reshape your data either using array.reshape(-1, 1) if "
#     623                     "your data has a single feature or array.reshape(1, -1) "
# --> 624                     "if it contains a single sample.".format(array))
#     625
#     626         # in the future np.flexible dtypes will be handled like object dtypes
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[0.62 0.64 0.53 ... 0.6  0.77 0.47].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
