# %%
import tabula
import time
import numpy as np
import pandas as pd

# %%
#Convertendo o arquivo
tabula.convert_into(r"dados/cbf.pdf", r"dados/cbf.csv", output_format="csv", pages="all", stream=True)
# Out:
# Got stderr: mai. 19, 2021 8:30:12 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri,Bold are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:13 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri,BoldItalic are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:13 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri,Bold are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:13 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri,BoldItalic are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:13 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri,Bold are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:13 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri,BoldItalic are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:13 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:13 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri,Italic are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:13 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:14 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri,Italic are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:14 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:14 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri,Italic are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:14 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Cambria are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:14 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Cambria are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:14 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri,Italic are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:14 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Cambria are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:14 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri,Italic are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:15 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri,Italic are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:15 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri,Italic are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:16 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri,Bold are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:16 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri,Bold are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:18 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:18 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:26 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:26 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:28 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:29 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:30 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:30 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:31 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:32 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:32 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:32 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:34 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:34 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:35 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:35 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:36 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:36 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:36 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:37 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCDEE+Calibri are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:39 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCEEE+Cambria,Italic are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:39 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCEEE+Cambria,Italic are not implemented in PDFBox and will be ignored
# mai. 19, 2021 8:30:39 PM org.apache.pdfbox.pdmodel.font.PDCIDFontType2 <init>
# INFORMAÇÕES: OpenType Layout tables used in font ABCEEE+Cambria,Italic are not implemented in PDFBox and will be ignored

# %%
#Lendo o csv gerado
df_cbf = pd.read_csv("dados/cbf.csv", sep=',')

# %%
#Renomeando as colunas
df_cbf.columns=["col1", "col2", "col3", "col4", "col5"]

# %%
#Removendo a última coluna
df_cbf = df_cbf.drop(columns='col5')

# %%
#Filtrando os valores não nulos na coluna 2
filtro_col2 = df_cbf['col2'].notnull()

# %%
#Selecionando as linhas cuja coluna 2 não é nula
df_cbf = df_cbf[filtro_col2]

# %%
#Filtrando os valores não nulos na coluna 4
filtro_atletas = df_cbf['col4'].notnull()

# %%
#Armazenando apenas os dados dos atletas
df_atletas = df_cbf[filtro_atletas]

# %%
#Filtrando os valores nulos na coluna 4 e não nulos na coluna 1
filtro_clubes = df_cbf['col4'].isna() & df_cbf['col1'].notnull()

# %%
df_cbf[filtro_clubes]
# Out:
#                                        col1  \
# 2237                         Clubes - Clubs
# 2238              Sociedade Ação Futebol/MT
# 2239               América Futebol Clube/MG
# 2240             Americano Futebol Clube/RJ
# 2241               Amparo Athletico Club/SP
# 2242        Angra dos Reis Esporte Clube/RJ
# 2243           Club Athletico Paranaense/PR
# 2244           Atlético Clube Goianiense/GO
# 2245              Clube Atlético Mineiro/MG
# 2246   Clube Atlético Matogrossense Ltda/MT
# 2247                  Avaí Futebol Clube/SC
# 2248                 Esporte Clube Bahia/BA
# 2249              Batatais Futebol Clube/SP
# 2250       Botafogo de Futebol E Regatas/RJ
# 2251               Brusque Futebol Clube/SC
# 2252       AE Campo Grande Futebol Clube/CE
# 2253                 Ceará Sporting Club/CE
# 2254   Associação Chapecoense de Futebol/SC
# 2255     Sport Club Corinthians Paulista/SP
# 2256             Coritiba Foot Ball Club/PR
# 2257                                 CRB/AL
# 2258              Criciúma Esporte Clube/SC
# 2259              Cruzeiro Esporte Clube/MG
# 2260                                 CSA/AL
# 2261                Cuiabá Esporte Clube/MT
# 2262        Clube de Regatas do Flamengo/RJ
# 2263            Fluminense Football Club/RJ
# 2264             Fortaleza Esporte Clube/CE
# 2265                 Goiás Esporte Clube/GO
# 2266    Grêmio Foot-Ball Porto Alegrense/RS
# 2267          Hercílio Luz Futebol Clube/SC
# 2268            Sport Club Internacional/RS
# 2269             Itumbiara Esporte Clube/GO
# 2270             Esporte Clube Juventude/RS
# 2271        Clube Atlético Metropolitano/SC
# 2272            Clube Náutico Capibaribe/PE
# 2273                Grêmio Novorizontino/SP
# 2274  Operário Ferroviário Esporte Clube/PR
# 2275       Sociedade Esportiva Palmeiras/SP
# 2276                        Paraná Clube/PR
# 2277     Associação Atlética Ponte Preta/SP
# 2278                 Red Bull Bragantino/SP
# 2279          Retrô Futebol Clube Brasil/PE
# 2280            Rio Branco Esporte Clube/SP
# 2281           Esporte Clube Santo André/SP
# 2282                Santos Futebol Clube/SP
# 2283              Esporte Clube São José/RS
# 2284             São Paulo Futebol Clube/SP
# 2285                Sport Club do Recife/PE
# 2286       Club de Regatas Vasco da Gama/RJ
# 2287             Vera Cruz Futebol Clube/PE
# 2288               Esporte Clube Vitória/BA
# 2289     EC XV de Novembro de Piracicaba/SP
# 2291                                  Total
#
#                                     col2 col3 col4
# 2237  (em Reais - Brazilian Reais - BRL)  NaN  NaN
# 2238                                 150   55  NaN
# 2239                             1016035  NaN  NaN
# 2240                                3000  NaN  NaN
# 2241                                1045  NaN  NaN
# 2242                             1000000  NaN  NaN
# 2243                          6376706,86  NaN  NaN
# 2244                             1455300  NaN  NaN
# 2245                         28875790,38  NaN  NaN
# 2246                                 150  NaN  NaN
# 2247                              132500  NaN  NaN
# 2248                           704586,29  NaN  NaN
# 2249                                1150  NaN  NaN
# 2250                          3915540,64  NaN  NaN
# 2251                                5000  NaN  NaN
# 2252                                1600  NaN  NaN
# 2253                             9815000  NaN  NaN
# 2254                             1110120  NaN  NaN
# 2255                            18395930  NaN  NaN
# 2256                           4848161,5  NaN  NaN
# 2257                               55000  NaN  NaN
# 2258                               10000  NaN  NaN
# 2259                             3517200  NaN  NaN
# 2260                              116000  NaN  NaN
# 2261                              100000  NaN  NaN
# 2262                         14201433,05  NaN  NaN
# 2263                           7146258,5  NaN  NaN
# 2264                              121500  NaN  NaN
# 2265                              560000  NaN  NaN
# 2266                             9939381  NaN  NaN
# 2267                                2200  NaN  NaN
# 2268                            19812982  NaN  NaN
# 2269                                2200  NaN  NaN
# 2270                              338000  NaN  NaN
# 2271                                2155  NaN  NaN
# 2272                               20000  NaN  NaN
# 2273                               45000  NaN  NaN
# 2274                              267000  NaN  NaN
# 2275                          6322614,58  NaN  NaN
# 2276                               70000  NaN  NaN
# 2277                              561000   56  NaN
# 2278                             6277160  NaN  NaN
# 2279                               17400  NaN  NaN
# 2280                                 110  NaN  NaN
# 2281                               22100  NaN  NaN
# 2282                          6139916,81  NaN  NaN
# 2283                                2000  NaN  NaN
# 2284                             7173960  NaN  NaN
# 2285                           945666,66  NaN  NaN
# 2286                             1899500  NaN  NaN
# 2287                                1200  NaN  NaN
# 2288                              483850  NaN  NaN
# 2289                           108752,68  NaN  NaN
# 2291                        163939305,95  NaN  NaN
