# %% [markdown]
# ![title](https://68.media.tumblr.com/853cf21e477e27168d3e62a792b8b592/tumblr_ooxp609mbo1uqdbpso1_400.gif)

# %% [markdown]
# ### Lionel Messi vs Cristiano Ronaldo

# %% [markdown]
# ### Fonte: https://data.world/makeovermonday/2020w15-messi-vs-ronaldo-stats
# ### https://www.ogol.com.br/home.php

# %% [markdown]
# ### La Liga
#
# #### Gols por temporada
# #### Assistências por temporada
# #### Jogos por temporada
# #### Média de gols por jogos
# #### Média de gols por minuto jogado
#
#
# ### Champions
#
# #### Gols por temporada
# #### Assistências por temporada
# #### Jogos por temporada
# #### Média de gols por jogos
# #### Média de gols por minuto jogado

# %% [markdown]
# ### Importando as bibliotecas necessárias

# %%
import matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Importando a base de dados para o nosso projeto
#
# Os dados abaixo de referem às informações

# %%
#Base de dados completa, com os gols de Messi e Ronaldo entre as temporadas 2009-2010 e 2017-2018

df_messironaldo = pd.read_excel('data/MessiRonaldo.xlsx')

# %%
#Base de dados com informações de Messi e Cristiano Ronaldo

df_messironaldo
# Out:
#      Season   Player  Liga_Goals  Liga_Asts  Liga_Aps  Liga_Mins  \
# 0   2017-18    Messi          34         12        36       2996
# 1   2017-18  Ronaldo          26          5        27       2297
# 2   2016-17    Messi          37          9        34       2832
# 3   2016-17  Ronaldo          25          6        29       2544
# 4   2015-16    Messi          26         16        33       2729
# 5   2015-16  Ronaldo          35         11        36       3184
# 6   2014-15    Messi          43         21        38       3375
# 7   2014-15  Ronaldo          48         16        35       3096
# 8   2013-14    Messi          28         12        31       2498
# 9   2013-14  Ronaldo          31         11        30       2537
# 10  2012-13    Messi          46         14        32       2629
# 11  2012-13  Ronaldo          34         11        34       2716
# 12  2011-12    Messi          50         20        37       3270
# 13  2011-12  Ronaldo          46         13        38       3353
# 14  2010-11    Messi          31         21        33       2862
# 15  2010-11  Ronaldo          40         13        34       2914
# 16  2009-10    Messi          34         13        35       2841
# 17  2009-10  Ronaldo          26         11        29       2462
#
#     Liga_Team_Goals  CL_Goals  CL_Asts  CL_Aps  CL_Mins  CL_Team_Goals
# 0                99         6        2      10      783             17
# 1                94        15        3      13     1170             33
# 2               116        11        2       9      810             26
# 3               106        12        5      13     1200             36
# 4               112         6        1       7      630             22
# 5               110        16        4      12     1109             28
# 6               110        10        6      13     1145             31
# 7               118        10        4      12     1064             24
# 8               100         8        1       7      630             21
# 9               104        17        6      11      991             41
# 10              115         8        3      11      827             18
# 11              103        12        1      12     1080             26
# 12              114        14        9      11      990             35
# 13              121        10        4      10      930             35
# 14               95        12        4      13     1050             30
# 15              102         6        4      12     1018             25
# 16               98         8        0      11      985             20
# 17              102         7        2       6      450             16

# %%
#Dados do Lionel Messi

df_messi = df_messironaldo.query('Player == "Messi"')

# %%
df_messi
# Out:
#      Season Player  Liga_Goals  Liga_Asts  Liga_Aps  Liga_Mins  \
# 0   2017-18  Messi          34         12        36       2996
# 2   2016-17  Messi          37          9        34       2832
# 4   2015-16  Messi          26         16        33       2729
# 6   2014-15  Messi          43         21        38       3375
# 8   2013-14  Messi          28         12        31       2498
# 10  2012-13  Messi          46         14        32       2629
# 12  2011-12  Messi          50         20        37       3270
# 14  2010-11  Messi          31         21        33       2862
# 16  2009-10  Messi          34         13        35       2841
#
#     Liga_Team_Goals  CL_Goals  CL_Asts  CL_Aps  CL_Mins  CL_Team_Goals
# 0                99         6        2      10      783             17
# 2               116        11        2       9      810             26
# 4               112         6        1       7      630             22
# 6               110        10        6      13     1145             31
# 8               100         8        1       7      630             21
# 10              115         8        3      11      827             18
# 12              114        14        9      11      990             35
# 14               95        12        4      13     1050             30
# 16               98         8        0      11      985             20

# %%
#Dados do Cristiano Ronaldo

df_ronaldo = df_messironaldo.query('Player == "Ronaldo"')

# %%
df_ronaldo
# Out:
#      Season   Player  Liga_Goals  Liga_Asts  Liga_Aps  Liga_Mins  \
# 1   2017-18  Ronaldo          26          5        27       2297
# 3   2016-17  Ronaldo          25          6        29       2544
# 5   2015-16  Ronaldo          35         11        36       3184
# 7   2014-15  Ronaldo          48         16        35       3096
# 9   2013-14  Ronaldo          31         11        30       2537
# 11  2012-13  Ronaldo          34         11        34       2716
# 13  2011-12  Ronaldo          46         13        38       3353
# 15  2010-11  Ronaldo          40         13        34       2914
# 17  2009-10  Ronaldo          26         11        29       2462
#
#     Liga_Team_Goals  CL_Goals  CL_Asts  CL_Aps  CL_Mins  CL_Team_Goals
# 1                94        15        3      13     1170             33
# 3               106        12        5      13     1200             36
# 5               110        16        4      12     1109             28
# 7               118        10        4      12     1064             24
# 9               104        17        6      11      991             41
# 11              103        12        1      12     1080             26
# 13              121        10        4      10      930             35
# 15              102         6        4      12     1018             25
# 17              102         7        2       6      450             16

# %% [markdown]
# ### La Liga
#
# Comparação entre os dois levando apenas em consideração os gols em La Liga

# %% [markdown]
# ![](https://cdn.clipart.email/aa04921fb81612f5c87869e0872191da_la-liga-pes-2020-leagues-competitions-pro-evolution-soccer-_256-256.png)

# %%
#Removendo as features referentes a Liga dos Campeões (Lionel Messi)

df_messi_liga = df_messi.drop(columns=['CL_Goals', 'CL_Asts', 'CL_Aps', 'CL_Mins', 'CL_Team_Goals'])

# %%
#Renomeando as features

#df_messi_liga = df_messi_liga.rename(columns={'Liga_Goals':'Liga_Goals_Messi', 'Liga_Asts':'Liga_Asts_Messi', 'Liga_Aps':'Liga_Aps_Messi', 'Liga_Mins':'Liga_Mins_Messi', 'Liga_Team_Goals':'Liga_Team_Goals_Messi'})

# %%
#Removendo as features referentes a Liga dos Campeões (Cristiano Ronaldo)

df_ronaldo_liga = df_ronaldo.drop(columns=['CL_Goals', 'CL_Asts', 'CL_Aps', 'CL_Mins', 'CL_Team_Goals'])

# %%
#Renomeando as features

#df_ronaldo_liga = df_ronaldo_liga.rename(columns={'Liga_Goals':'Liga_Goals_Ronaldo', 'Liga_Asts':'Liga_Asts_Ronaldo', 'Liga_Aps':'Liga_Aps_Ronaldo', 'Liga_Mins':'Liga_Mins_Ronaldo', 'Liga_Team_Goals':'Liga_Team_Goals_Ronaldo'})

# %%
#Gols do Lionel Messi em La Liga

plt.bar(df_messi_liga['Season'].sort_values(ascending=True), df_messi_liga['Liga_Goals'], color='red')

#Título do gráfico
plt.title("Gols do Lionel Messi na La Liga")

#Título do eixo Y
plt.ylabel('Gols')

#Rotação dos elementos do eixo X
plt.xticks(rotation=45)

plt.show()

# %%
#Gols do Cristiano Ronaldo em La Liga

plt.bar(df_ronaldo_liga['Season'].sort_values(ascending=True), df_ronaldo_liga['Liga_Goals'], color='blue')

plt.title("Gols do Cristiano Ronaldo na La Liga")
plt.ylabel('Gols')
plt.xticks(rotation=45)

plt.show()

# %%
#Mesclando as bases de Messi e Ronaldo (dados da La Liga)

df_messi_ronaldo_liga = df_messi_liga.merge(df_ronaldo_liga, on=('Season'), suffixes=('_Messi', '_Ronaldo'))

# %%
#Ordenando os dados pela coluna 'Season' (do menor ano para o mauir)

df_messi_ronaldo_liga = df_messi_ronaldo_liga.sort_values(by=['Season'], ascending=True)

# %%
#Gráfico comparando os gols de Messi e Cristiando Ronaldo

df_messi_ronaldo_liga.plot.bar(x='Season', y=['Liga_Goals_Messi', 'Liga_Goals_Ronaldo'], rot=45, width=.7)

# %%
#Gráfico comparando os gols de Messi e Cristiando Ronaldo

#Localização dos itens no eixo X
x = np.arange(len(df_messi_ronaldo_liga['Season']))

#Expessura das barras
expessura_bar = .8

fig, ax = plt.subplots()
df1 = ax.bar(2*x - expessura_bar/2, df_messi_ronaldo_liga['Liga_Goals_Messi'], label="Gols - Messi", color='red')
df2 = ax.bar(2*x + expessura_bar/2, df_messi_ronaldo_liga['Liga_Goals_Ronaldo'], label="Gols - Ronaldo", color="blue")

#Customização dos eixos X e Y
ax.set_ylabel("Gols", rotation=90)
ax.set_title("Lionel Messi vs Cristiano Ronaldo - Gols")
ax.set_xticks(2*x)
ax.set_xticklabels(df_messi_ronaldo_liga['Season'], rotation=45)
ax.legend()

def autolabel(dfs):
    for df in dfs:
        tamanho = df.get_height()
        ax.annotate('{}'.format(tamanho),
                    xy = (df.get_x() + df.get_width()/2, tamanho),
                    xytext = (0,3),
                    textcoords = "offset points",
                    ha = 'center', va='bottom')
autolabel(df1)
autolabel(df2)

fig.tight_layout()

#Tamanho do gráfico
plt.figure(figsize=(10,10), constrained_layout=False)

#Salvar o gráfico gerado
#fig.savefig('grafico.png', format='png')

#Exibir o gráfico
plt.show()

# %%
#Distribuição de gols de Lionel Messi e Cristiano Ronaldo em La Liga

df_messi_ronaldo_liga.boxplot(column = ['Liga_Goals_Messi', 'Liga_Goals_Ronaldo'])

# %%
#Gráfico de dispersão dos gols de Lionel Messi

plt.scatter(df_messi_ronaldo_liga['Season'], df_messi_ronaldo_liga['Liga_Goals_Messi'])

# %%
#Correlacionando os dados de Lionel Messi e Cristiano Ronaldo em La Liga

df_messi_ronaldo_liga.corr().style.format("{:.2}").background_gradient(cmap=plt.get_cmap("coolwarm"), axis=1)
# Out:
# <style  type="text/css" >
#     #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row0_col1 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row0_col2 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row0_col3 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row0_col4 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row0_col5 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row0_col7 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row0_col8 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row0_col9 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row1_col0 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row1_col2 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row1_col3 {
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row1_col5 {
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row1_col6 {
#             background-color:  #e67259;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row1_col7 {
#             background-color:  #ee8468;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row1_col8 {
#             background-color:  #ed8366;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row1_col9 {
#             background-color:  #f3c8b2;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row2_col0 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row2_col1 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row2_col3 {
#             background-color:  #c43032;
#             color:  #f1f1f1;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row2_col5 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row2_col6 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row2_col7 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row2_col8 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row2_col9 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row3_col0 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row3_col1 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row3_col2 {
#             background-color:  #c43032;
#             color:  #f1f1f1;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row3_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row3_col5 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row3_col6 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row3_col7 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row3_col8 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row3_col9 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row4_col0 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row4_col2 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row4_col3 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row4_col5 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row4_col6 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row4_col7 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row4_col8 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row4_col9 {
#             background-color:  #f2cab5;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row5_col0 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row5_col1 {
#             background-color:  #d44e41;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row5_col2 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row5_col3 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row5_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row5_col6 {
#             background-color:  #ed8366;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row5_col7 {
#             background-color:  #e97a5f;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row5_col8 {
#             background-color:  #e9785d;
#             color:  #000000;
#         }    #T_cacf03ae_d371_11ea_a30e_8593c128f3f5row5_col9 {
#             background-color:  #f6a385;
#             color:  #000000;

# %% [markdown]
# ### Champions League
#
# Comparação entre os dois levando apenas em consideração os gols na Champions League

# %% [markdown]
# ![](https://logospng.org/download/uefa-champions-league/logo-uefa-champions-league-256.png)

# %%
#Removendo as features referentes a La Liga (Lionel Messi)

df_messi_champions = df_messi.drop(columns=['Liga_Goals', 'Liga_Asts', 'Liga_Aps', 'Liga_Mins', 'Liga_Team_Goals'])

# %%
#Removendo as features referentes a La Liga (Cristiano Ronaldo)

df_ronaldo_champions = df_ronaldo.drop(columns=['Liga_Goals', 'Liga_Asts', 'Liga_Aps', 'Liga_Mins', 'Liga_Team_Goals'])

# %%
#Gols do Lionel Messi na Champions League

plt.barh(df_messi_champions['Season'], df_messi_champions['CL_Goals'], color="red")

plt.title("Gols do Lionel Messi na Champions League")
# Out:
# Text(0.5, 1.0, 'Gols do Lionel Messi na Champions League')

# %%
#Gols do Cristiano Ronaldo na Champions League

plt.barh(df_ronaldo_champions['Season'], df_ronaldo['CL_Goals'], color='blue')

plt.title("Gols do Cristiano Ronaldo na Champions League")
# Out:
# Text(0.5, 1.0, 'Gols do Cristiano Ronaldo na Champions League')

# %%
#Mesclando as bases de Messi e Ronaldo (dados da Champions League)

df_messi_ronaldo_champions = df_messi_champions.merge(df_ronaldo_champions, on=('Season'), suffixes=('_Messi', '_Ronaldo'))

# %%
#Ordenando os dados pela coluna 'Season' (do menor ano para o mauir)

df_messi_ronaldo_champions = df_messi_ronaldo_champions.sort_values(by=['Season'], ascending=True)

# %%
#Informações da base de dados criada

df_messi_ronaldo_champions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 8 to 0
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Season                 9 non-null      object
#  1   Player_Messi           9 non-null      object
#  2   CL_Goals_Messi         9 non-null      int64
#  3   CL_Asts_Messi          9 non-null      int64
#  4   CL_Aps_Messi           9 non-null      int64
#  5   CL_Mins_Messi          9 non-null      int64
#  6   CL_Team_Goals_Messi    9 non-null      int64
#  7   Player_Ronaldo         9 non-null      object
#  8   CL_Goals_Ronaldo       9 non-null      int64
#  9   CL_Asts_Ronaldo        9 non-null      int64
#  10  CL_Aps_Ronaldo         9 non-null      int64
#  11  CL_Mins_Ronaldo        9 non-null      int64
#  12  CL_Team_Goals_Ronaldo  9 non-null      int64
# dtypes: int64(10), object(3)
# memory usage: 1008.0+ bytes

# %%
#Descrição da base de dados

df_messi_ronaldo_champions.describe()
# Out:
#        CL_Goals_Messi  CL_Asts_Messi  CL_Aps_Messi  CL_Mins_Messi  \
# count        9.000000       9.000000      9.000000       9.000000
# mean         9.222222       3.111111     10.222222     872.222222
# std          2.728451       2.848001      2.223611     181.598305
# min          6.000000       0.000000      7.000000     630.000000
# 25%          8.000000       1.000000      9.000000     783.000000
# 50%          8.000000       2.000000     11.000000     827.000000
# 75%         11.000000       4.000000     11.000000     990.000000
# max         14.000000       9.000000     13.000000    1145.000000
#
#        CL_Team_Goals_Messi  CL_Goals_Ronaldo  CL_Asts_Ronaldo  CL_Aps_Ronaldo  \
# count             9.000000          9.000000         9.000000        9.000000
# mean             24.444444         11.666667         3.666667       11.222222
# std               6.346478          3.840573         1.500000        2.166667
# min              17.000000          6.000000         1.000000        6.000000
# 25%              20.000000         10.000000         3.000000       11.000000
# 50%              22.000000         12.000000         4.000000       12.000000
# 75%              30.000000         15.000000         4.000000       12.000000
# max              35.000000         17.000000         6.000000       13.000000
#
#        CL_Mins_Ronaldo  CL_Team_Goals_Ronaldo
# count         9.000000               9.000000
# mean       1001.333333              29.333333
# std         223.345584               7.615773
# min         450.000000              16.000000
# 25%         991.000000              25.000000
# 50%        1064.000000              28.000000
# 75%        1109.000000              35.000000
# max        1200.000000              41.000000

# %% [markdown]
# ### Referências:
#
# ### https://matplotlib.org/3.2.2/gallery/lines_bars_and_markers/barchart.html#sphx-glr-gallery-lines-bars-and-markers-barchart-py
# ### https://www.it-swarm.dev/pt/python/qual-e-diferenca-entre-juntar-e-mesclar-no-pandas/1044758653/
# ### https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_values.html
