# %% [markdown]
# ### Fonte dos dados: https://ourworldindata.org/coronavirus-source-data

# %% [markdown]
# ### Importando as bibliotecas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Dados do COVID-19

# %%
df_covid = pd.read_excel("https://covid.ourworldindata.org/data/owid-covid-data.xlsx")

# %%
df_covid[(df_covid['location'] == 'Brazil')]
# Out:
#      iso_code      continent location        date  total_cases  new_cases  \
# 2854      BRA  South America   Brazil  2019-12-31            0          0
# 2855      BRA  South America   Brazil  2020-01-01            0          0
# 2856      BRA  South America   Brazil  2020-01-02            0          0
# 2857      BRA  South America   Brazil  2020-01-03            0          0
# 2858      BRA  South America   Brazil  2020-01-04            0          0
# ...       ...            ...      ...         ...          ...        ...
# 3008      BRA  South America   Brazil  2020-06-02       526447      11598
# 3009      BRA  South America   Brazil  2020-06-03       555383      28936
# 3010      BRA  South America   Brazil  2020-06-04       584016      28633
# 3011      BRA  South America   Brazil  2020-06-05       614941      30925
# 3012      BRA  South America   Brazil  2020-06-06       614941          0
#
#       total_deaths  new_deaths  total_cases_per_million  \
# ...
