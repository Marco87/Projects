# %% [markdown]
# ![](https://media1.tenor.com/images/09190fd743ff2f962bdfd57987efc67f/tenor.gif?itemid=17055695)

# %% [markdown]
# ### Fonte dos dados: https://brasil.io/covid19/

# %% [markdown]
# ![](https://files.adventistas.org/institucional/pt/sites/19/2020/03/covid19.jpg)

# %% [markdown]
# ### Importando as bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Carregando os dados

df_covid = pd.read_csv("https://brasil.io/dataset/covid19/caso?format=csv", sep=",", encoding="utf8")

# %%
#Renomeando as colunas
# Out:
#               date state                    city place_type  confirmed  \
# 0       2020-05-30    AL                  Anadia       city         31
# 1       2020-05-30    AL               Arapiraca       city        324
# 2       2020-05-30    AL                 Atalaia       city        149
# 3       2020-05-30    AL  Barra de Santo Antônio       city         18
# 4       2020-05-30    AL     Barra de São Miguel       city         20
# ...            ...   ...                     ...        ...        ...
# 136854  2020-02-27    SP                     NaN      state          1
# 136855  2020-02-26    SP               São Paulo       city          1
# 136856  2020-02-26    SP                     NaN      state          1
# 136857  2020-02-25    SP               São Paulo       city          1
# 136858  2020-02-25    SP                     NaN      state          1
#
#         deaths  is_last  estimated_population_2019  city_ibge_code  \
# 0            1     True                    17545.0       2700201.0
# 1           12     True                   231747.0       2700300.0
# 2            3     True                    47185.0       2700409.0
# 3            2     True                    15932.0       2700508.0
# 4            1     True                     8322.0       2700607.0
# ...        ...      ...                        ...             ...
# 136854       0    False                 45919049.0            35.0
# 136855       0    False                 12252023.0       3550308.0
# 136856       0    False                 45919049.0            35.0
# 136857       0    False                 12252023.0       3550308.0
# 136858       0    False                 45919049.0            35.0
#
#         confirmed_per_100k_inhabitants  death_rate
# 0                            176.68852      0.0323
# 1                            139.80764      0.0370
# 2                            315.77832      0.0201
# 3                            112.98017      0.1111
# 4                            240.32684      0.0500
# ...                                ...         ...
# 136854                         0.00218      0.0000
# 136855                         0.00816      0.0000
# 136856                         0.00218      0.0000
# 136857                         0.00816      0.0000
# 136858                         0.00218      0.0000
#
# [136859 rows x 11 columns]
